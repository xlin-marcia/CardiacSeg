# %% [markdown]
# 1.   There's a lot of complications with using nnUNet, especially the fact that each dataset has to be in a certain format and also setting environment variables in a certain
# 2.   Another thing to note is that there seems be a few changes between nnUNetv1 and nnUNetv2 in terms of creating the compatible dataset structure
#
# Processed Datasets: https://drive.google.com/drive/folders/18ZdrFsY3X2QUgx2kaYxZiUnAcYAN82bJ?usp=sharing

# %%
! pip install nnunetv2
# Out:
# ...
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# ...
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# ...

# %%
! pip install triton
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 4.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# #### The nnUNet_raw file contains the preprocessed dataset structure

# %%
import os

os.environ['nnUNet_raw'] = '/content/drive/MyDrive/NTU/nnUNet_raw'
os.environ['nnUNet_preprocessed'] = '/content/nnUNet_preprocessed'
os.environ['RESULTS_FOLDER'] = '/content/nnUNet_trained_models'

os.makedirs(os.environ['nnUNet_raw'], exist_ok=True)
os.makedirs(os.environ['nnUNet_preprocessed'], exist_ok=True)
os.makedirs(os.environ['RESULTS_FOLDER'], exist_ok=True)

# %%
# !nnUNetv2_plan_and_preprocess -d 27 --verify_dataset_integrity
# Out:
# nnUNet_results is not defined and nnU-Net cannot be used for training or inference. If this is not intended behavior, please read documentation/setting_up_paths.md for information on how to set this up.
# Fingerprint extraction...
# Dataset027_ACDC
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1997
# NiftiImageIO (0x555d7ba07090): /content/drive/MyDrive/NTU/nnUNet_raw/Dataset027_ACDC/imagesTr/patient001_frame01_0000.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1997
# NiftiImageIO (0x555d7ba07090): /content/drive/MyDrive/NTU/nnUNet_raw/Dataset027_ACDC/imagesTr/patient001_frame01_0000.nii.gz has unexpected scales in sform
#
# Using <class 'nnunetv2.imageio.simpleitk_reader_writer.SimpleITKIO'> as reader/writer
# ...

# %%
# !nnUNetv2_plan_and_preprocess -d 27 -np 4 -c 3d_fullres --verify_dataset_integrity
# Out:
# Streaming output truncated to the last 5000 lines.
# NiftiImageIO (0x5a3bc9730030): /content/drive/MyDrive/NTU/nnUNet_raw/Dataset027_ACDC/labelsTr/patient083_frame08.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1997
# NiftiImageIO (0x56f57950d280): /content/drive/MyDrive/NTU/nnUNet_raw/Dataset027_ACDC/labelsTr/patient077_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1997
# NiftiImageIO (0x56f57950d280): /content/drive/MyDrive/NTU/nnUNet_raw/Dataset027_ACDC/labelsTr/patient077_frame01.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1997
# NiftiImageIO (0x562498d8f680): /content/drive/MyDrive/NTU/nnUNet_raw/Dataset027_ACDC/labelsTr/patient096_frame08.nii.gz has unexpected scales in sform
#
# ...

# %% [markdown]
# #### The number 27 refers to the Dataset027, which is according to the nnUNet requirement for running any part of the code

# %%
os.environ['nnUNet_results'] = '/content/nnUNet_results'
# !echo $nnUNet_results
# !nnUNetv2_train 27 3d_fullres 0
# Out:
# /content/nnUNet_results
#
# ############################
# INFO: You are using the old nnU-Net default plans. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Using device: cuda:0
# /usr/local/lib/python3.10/dist-packages/nnunetv2/training/nnUNetTrainer/nnUNetTrainer.py:164: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.grad_scaler = GradScaler() if self.device.type == 'cuda' else None
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# ...
